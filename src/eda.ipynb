# %%
from get_data import GetData
df, features = GetData().get_data()
# Out:
# === Sellin input ===
# Transacciones cargadas: 100,000
# Periodo: 2023-04-29 a 2024-04-28
# Productos únicos: 4
# Categorías: 4
# === Inflation input ===
# Inflación agregada
# Temperatura NO disponible
# Precios de competencia NO disponibles

# %%
df.iloc[0]
# Out:
# CustomerID                     109318
# ProductID                           C
# Quantity                            7
# Price                       80.079844
# PaymentMethod                    Cash
# ProductCategory                 Books
# DiscountApplied               18.6771
# TotalAmount                455.862764
# Date                       2023-12-26
# year                             2023
# month                              12
# year_month                     202312
# day_of_week                         1
# day_of_month                       26
# hour                               12
# is_weekend                          0
# quarter                             4
# Direction           176 Andrew Cliffs
# City                       Baileyfort
# State                              HI
# ZipCode                         93354
# payment_encoded                     0
# category_encoded                    0
# has_discount                        1
# discount_level                      2
# ...

# %%
DiscountApplied
# Out:
# Index(['Date', 'ProductID', 'Price', 'category_encoded', 'demand',
#        'CustomerID', 'TotalAmount', 'day_of_week', 'hour', 'is_weekend',
#        'month', 'quarter', 'has_discount', 'discount_level', 'DiscountApplied',
#        'store_encoded', 'payment_encoded', 'InflationMonth', 'InflationYear'],
#       dtype='str')

# %%
df_aggregated.iloc[0]
# Out:
# Date                2023-04-29
# ProductID                    A
# Price                14.848622
# category_encoded             2
# demand                       4
# CustomerID                   1
# TotalAmount          53.510366
# day_of_week                  5
# hour                      23.0
# is_weekend                   1
# month                        4
# quarter                      2
# has_discount                 1
# discount_level               1
# DiscountApplied       9.906849
# store_encoded            80461
# payment_encoded              3
# InflationMonth        0.004028
# InflationYear         0.049469
# Name: 0, dtype: object

# %%
df_aggregated#.columns


'Date', 'ProductID', 'Price', 'demand'


'day_of_week',
'hour',
'is_weekend',
'month',
'quarter',
'has_discount',
'discount_level',
'category_encoded',
'store_encoded',
'InflationRate',
'Temperature',
'CompetitorPrice',
'price_vs_competitor'

'', ,
       'CustomerID', 'TotalAmount', 'day_of_week', 'hour', 'is_weekend',
       'month', 'quarter', 'has_discount', 'discount_level', 'DiscountApplied',
       'store_encoded', 'payment_encoded', 'InflationMonth', 'InflationYear'
# Out:
#   Cell In[8], line 21
#     '', ,
#         ^
# SyntaxError: invalid syntax
