# %%
from get_data import GetData
from demand_calculation import calculate_demand
df, features = GetData().get_data()
df_aggregated = calculate_demand(df)
# Out:
# === Sellin input ===
# Transacciones cargadas: 100,000
# Periodo: 2023-04-29 a 2024-04-28
# Productos únicos: 4
# Categorías: 4
# === Inflation input ===
# Inflación agregada
# Temperatura NO disponible
# Precios de competencia NO disponibles

# %%
df_aggregated.iloc[0]
# Out:
# Date                 2023-04-29
# ProductID                     A
# Price                 14.848622
# ProductCategory     Electronics
# demand                        4
# CustomerID                    1
# TotalAmount           53.510366
# day_of_week                   5
# hour                       23.0
# is_weekend                    1
# month                         4
# quarter                       2
# has_discount                  1
# discount_level                1
# DiscountApplied        9.906849
# category_encoded              2
# store_encoded             80461
# payment_encoded               3
# InflationMonth         0.004028
# InflationYear          0.049469
# Name: 0, dtype: object
